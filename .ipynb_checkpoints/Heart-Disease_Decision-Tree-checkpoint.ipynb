# %% [markdown]
# # Case Study 3 - Heart Disease

# %%
from sklearn import tree
import pandas as pd
import graphviz

# %%
patient_data = pd.read_csv('heart.xls')

# %%
patient_data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [1025 rows x 14 columns]

# %% [markdown]
# ### Check for null values in the dataset

# %%
patient_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# ### There are none null values in the dataset

# %%
X, y = patient_data.drop('target', axis='columns'), patient_data[['target']]

# %%
X_labels = X.columns

# %% [markdown]
# ### Split the dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.2, random_state=69)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((820, 13), (205, 13), (820, 1), (205, 1))

# %% [markdown]
# ### Scale the features using MinMax Normalization method.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mima_scaler = MinMaxScaler()

# %%
mima_scaled_X_train = mima_scaler.fit_transform(X_train)

# %%
mima_scaled_X_train = pd.DataFrame(mima_scaled_X_train, columns=X_labels)

# %%
mima_scaled_X_test = mima_scaler.fit_transform(X_test)

# %%
mima_scaled_X_test = pd.DataFrame(mima_scaled_X_test, columns=X_labels)

# %% [markdown]
# ### Let's make a decision tree

# %%
clf = tree.DecisionTreeClassifier()

# %%
base_tree = clf.fit(mima_scaled_X_train, y_train)

# %% [markdown]
# ### Ploting of the tree

# %%
tree.plot_tree(base_tree)
# Out:
# [Text(0.4487920168067227, 0.95, 'x[2] <= 0.167\ngini = 0.5\nsamples = 820\nvalue = [400, 420]'),
#  Text(0.19327731092436976, 0.85, 'x[11] <= 0.125\ngini = 0.371\nsamples = 394\nvalue = [297, 97]'),
#  Text(0.1092436974789916, 0.75, 'x[12] <= 0.833\ngini = 0.5\nsamples = 174\nvalue = [88.0, 86.0]'),
#  Text(0.05042016806722689, 0.65, 'x[7] <= 0.37\ngini = 0.367\nsamples = 95\nvalue = [23, 72]'),
#  Text(0.03361344537815126, 0.55, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.06722689075630252, 0.55, 'x[8] <= 0.5\ngini = 0.285\nsamples = 87\nvalue = [15.0, 72.0]'),
#  Text(0.03361344537815126, 0.45, 'x[4] <= 0.435\ngini = 0.036\nsamples = 55\nvalue = [1, 54]'),
#  Text(0.01680672268907563, 0.35, 'gini = 0.0\nsamples = 51\nvalue = [0, 51]'),
#  Text(0.05042016806722689, 0.35, 'x[9] <= 0.097\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.03361344537815126, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06722689075630252, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.10084033613445378, 0.45, 'x[6] <= 0.25\ngini = 0.492\nsamples = 32\nvalue = [14, 18]'),
#  Text(0.08403361344537816, 0.35, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.11764705882352941, 0.35, 'x[4] <= 0.443\ngini = 0.476\nsamples = 23\nvalue = [14, 9]'),
#  Text(0.10084033613445378, 0.25, 'x[3] <= 0.198\ngini = 0.291\nsamples = 17\nvalue = [14, 3]'),
#  Text(0.08403361344537816, 0.15, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.11764705882352941, 0.15, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.13445378151260504, 0.25, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.16806722689075632, 0.65, 'x[9] <= 0.105\ngini = 0.292\nsamples = 79\nvalue = [65, 14]'),
#  Text(0.15126050420168066, 0.55, 'x[0] <= 0.271\ngini = 0.499\nsamples = 27\nvalue = [13, 14]'),
#  Text(0.13445378151260504, 0.45, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.16806722689075632, 0.45, 'x[4] <= 0.255\ngini = 0.346\nsamples = 18\nvalue = [4, 14]'),
#  Text(0.15126050420168066, 0.35, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.18487394957983194, 0.35, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.18487394957983194, 0.55, 'gini = 0.0\nsamples = 52\nvalue = [52, 0]'),
#  Text(0.2773109243697479, 0.75, 'x[3] <= 0.142\ngini = 0.095\nsamples = 220\nvalue = [209, 11]'),
#  Text(0.23529411764705882, 0.65, 'x[4] <= 0.245\ngini = 0.486\nsamples = 12\nvalue = [7, 5]'),
#  Text(0.2184873949579832, 0.55, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.25210084033613445, 0.55, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.31932773109243695, 0.65, 'x[4] <= 0.401\ngini = 0.056\nsamples = 208\nvalue = [202, 6]'),
#  Text(0.2857142857142857, 0.55, 'x[7] <= 0.263\ngini = 0.023\nsamples = 175\nvalue = [173, 2]'),
#  Text(0.2689075630252101, 0.45, 'x[9] <= 0.097\ngini = 0.172\nsamples = 21\nvalue = [19, 2]'),
#  Text(0.25210084033613445, 0.35, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2857142857142857, 0.35, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.3025210084033613, 0.45, 'gini = 0.0\nsamples = 154\nvalue = [154, 0]'),
#  Text(0.35294117647058826, 0.55, 'x[4] <= 0.405\ngini = 0.213\nsamples = 33\nvalue = [29, 4]'),
#  Text(0.33613445378151263, 0.45, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.3697478991596639, 0.45, 'gini = 0.0\nsamples = 29\nvalue = [29, 0]'),
#  Text(0.7043067226890757, 0.85, 'x[12] <= 0.833\ngini = 0.367\nsamples = 426\nvalue = [103, 323]'),
#  Text(0.5462184873949579, 0.75, 'x[0] <= 0.552\ngini = 0.254\nsamples = 315\nvalue = [47, 268]'),
#  Text(0.453781512605042, 0.65, 'x[9] <= 0.573\ngini = 0.087\nsamples = 197\nvalue = [9, 188]'),
#  Text(0.4369747899159664, 0.55, 'x[4] <= 0.062\ngini = 0.069\nsamples = 195\nvalue = [7.0, 188.0]'),
#  Text(0.40336134453781514, 0.45, 'x[4] <= 0.043\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.3865546218487395, 0.35, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.42016806722689076, 0.35, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.47058823529411764, 0.45, 'x[3] <= 0.142\ngini = 0.041\nsamples = 190\nvalue = [4, 186]'),
#  Text(0.453781512605042, 0.35, 'x[3] <= 0.118\ngini = 0.332\nsamples = 19\nvalue = [4, 15]'),
#  Text(0.4369747899159664, 0.25, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.47058823529411764, 0.25, 'x[1] <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.453781512605042, 0.15, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.48739495798319327, 0.15, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.48739495798319327, 0.35, 'gini = 0.0\nsamples = 171\nvalue = [0, 171]'),
#  Text(0.47058823529411764, 0.55, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6386554621848739, 0.65, 'x[1] <= 0.5\ngini = 0.437\nsamples = 118\nvalue = [38, 80]'),
#  Text(0.5714285714285714, 0.55, 'x[0] <= 0.594\ngini = 0.107\nsamples = 53\nvalue = [3, 50]'),
#  Text(0.5378151260504201, 0.45, 'x[4] <= 0.317\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.5210084033613446, 0.35, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5546218487394958, 0.35, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6050420168067226, 0.45, 'x[0] <= 0.625\ngini = 0.04\nsamples = 49\nvalue = [1.0, 48.0]'),
#  Text(0.5882352941176471, 0.35, 'x[2] <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.5714285714285714, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6050420168067226, 0.25, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.6218487394957983, 0.35, 'gini = 0.0\nsamples = 42\nvalue = [0, 42]'),
#  Text(0.7058823529411765, 0.55, 'x[11] <= 0.125\ngini = 0.497\nsamples = 65\nvalue = [35, 30]'),
#  Text(0.6722689075630253, 0.45, 'x[4] <= 0.304\ngini = 0.394\nsamples = 37\nvalue = [10, 27]'),
#  Text(0.6554621848739496, 0.35, 'x[9] <= 0.427\ngini = 0.069\nsamples = 28\nvalue = [1, 27]'),
#  Text(0.6386554621848739, 0.25, 'gini = 0.0\nsamples = 27\nvalue = [0, 27]'),
#  Text(0.6722689075630253, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6890756302521008, 0.35, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.7394957983193278, 0.45, 'x[0] <= 0.802\ngini = 0.191\nsamples = 28\nvalue = [25, 3]'),
#  Text(0.7226890756302521, 0.35, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]'),
#  Text(0.7563025210084033, 0.35, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8623949579831933, 0.75, 'x[7] <= 0.546\ngini = 0.5\nsamples = 111\nvalue = [56.0, 55.0]'),
#  Text(0.8109243697478992, 0.65, 'x[9] <= 0.04\ngini = 0.142\nsamples = 26\nvalue = [24, 2]'),
#  Text(0.7941176470588235, 0.55, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8277310924369747, 0.55, 'gini = 0.0\nsamples = 24\nvalue = [24, 0]'),
#  Text(0.9138655462184874, 0.65, 'x[9] <= 0.315\ngini = 0.469\nsamples = 85\nvalue = [32, 53]'),
#  Text(0.8613445378151261, 0.55, 'x[3] <= 0.307\ngini = 0.408\nsamples = 70\nvalue = [20, 50]'),
#  Text(0.8067226890756303, 0.45, 'x[10] <= 0.25\ngini = 0.157\nsamples = 35\nvalue = [3, 32]'),
#  Text(0.7899159663865546, 0.35, 'x[2] <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.773109243697479, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8067226890756303, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8235294117647058, 0.35, 'gini = 0.0\nsamples = 29\nvalue = [0, 29]'),
#  Text(0.9159663865546218, 0.45, 'x[10] <= 0.75\ngini = 0.5\nsamples = 35\nvalue = [17, 18]'),
#  Text(0.8739495798319328, 0.35, 'x[9] <= 0.161\ngini = 0.408\nsamples = 21\nvalue = [15, 6]'),
#  Text(0.8403361344537815, 0.25, 'x[3] <= 0.632\ngini = 0.231\nsamples = 15\nvalue = [13, 2]'),
#  Text(0.8235294117647058, 0.15, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.8571428571428571, 0.15, 'x[7] <= 0.656\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.8403361344537815, 0.05, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8739495798319328, 0.05, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.907563025210084, 0.25, 'x[3] <= 0.679\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.8907563025210085, 0.15, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.9243697478991597, 0.15, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.957983193277311, 0.35, 'x[3] <= 0.83\ngini = 0.245\nsamples = 14\nvalue = [2, 12]'),
#  Text(0.9411764705882353, 0.25, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.9747899159663865, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9663865546218487, 0.55, 'x[9] <= 0.645\ngini = 0.32\nsamples = 15\nvalue = [12, 3]'),
#  Text(0.9495798319327731, 0.45, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.9831932773109243, 0.45, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]')]

# %%
train_pred = base_tree.predict(mima_scaled_X_train)

# %%
test_pred = base_tree.predict(mima_scaled_X_test)

# %% [markdown]
# ### All the performace metrics of the tree

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %%
train_accuracy = accuracy_score(y_train, train_pred)
train_precision = precision_score(y_train, train_pred)
train_recall = recall_score(y_train, train_pred)
train_f1 = f1_score(y_train, train_pred)
train_roc_auc = roc_auc_score(y_train, train_pred)

# %%
test_accuracy = accuracy_score(y_test, test_pred)
test_precision = precision_score(y_test, test_pred)
test_recall = recall_score(y_test, test_pred)
test_f1 = f1_score(y_test, test_pred)
test_roc_auc = roc_auc_score(y_test, test_pred)

# %%
print(f'For all metrics on training data:\nAccuracy = {train_accuracy}.\nPrecision = {train_precision}.\nRecall = {train_recall}.\nF1 Score = {train_f1}.\nROC-AUC = {train_roc_auc}.')
# Out:
# For all metrics on training data:
# Accuracy = 1.0.
# Precision = 1.0.
# Recall = 1.0.
# F1 Score = 1.0.
# ROC-AUC = 1.0.

# %%
print(f'For all metrics on testing data:\nAccuracy = {test_accuracy}.\nPrecision = {test_precision}.\nRecall = {test_recall}.\nF1 Score = {test_f1}.\nROC-AUC = {test_roc_auc}.')
# Out:
# For all metrics on testing data:
# Accuracy = 0.8780487804878049.
# Precision = 0.9175257731958762.
# Recall = 0.839622641509434.
# F1 Score = 0.8768472906403941.
# ROC-AUC = 0.8794072803506766.

# %% [markdown]
# ### Ploting the decision tree using Graphviz library

# %%
dot_data = tree.export_graphviz(clf, out_file=None, feature_names=X_labels, class_names=['No Disease', 'Disease'], filled=True, rounded=True, special_characters=True)

# %%
tree_graph = graphviz.Source(dot_data)

# %%
tree_graph

# %%
tree_graph.render('Heart-Disease')
# Out:
# 'Heart-Disease.pdf'
